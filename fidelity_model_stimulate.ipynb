# %%
import torch
import torch.nn as nn
import numpy as np
import os
from collections import deque

# %% [markdown]
# ## 1D-CNN 特征提取器

# %%
def create_raw_data_cnn():
    """创建一个用于处理原始传感器数据的1D-CNN模块。"""
    # 以下序贯模型来自 feature_edge_node_stimulate.ipynb 中 feature_extractor 的结构
    raw_data_processor = nn.Sequential(
        nn.Conv1d(in_channels=11, out_channels=64, kernel_size=3, padding='same'), 
        nn.ReLU(), 
        nn.BatchNorm1d(64),
        nn.MaxPool1d(kernel_size=2, stride=2), # Length: 200 -> 100
        
        nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding='same'), 
        nn.ReLU(), 
        nn.BatchNorm1d(128),
        nn.MaxPool1d(kernel_size=2, stride=2), # Length: 100 -> 50

        nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, padding='same'), 
        nn.ReLU(), 
        nn.BatchNorm1d(256),
        nn.MaxPool1d(kernel_size=2, stride=2), # Length: 50 -> 25
        
        nn.Flatten() # 输出一个扁平化的向量
    )
    return raw_data_processor

# %% [markdown]
# ## 历史特征池管理器

# %%
class HistoricalFeaturePool:
    """管理从边缘节点接收的历史特征，并提供固定长度的序列。"""
    def __init__(self, max_sequence_length=60):
        """
        初始化特征池。
        :param max_sequence_length: LSTM期望的序列长度。例如，60代表30秒的历史（每0.5秒一个特征）。
        """
        self.max_len = max_sequence_length
        # 使用deque可以高效地维持一个固定大小的队列
        self.feature_deque = deque(maxlen=self.max_len)
        print(f"Historical Feature Pool initialized with max length {self.max_len}.")

    def add_feature(self, feature_vector: np.ndarray):
        """添加一个新的特征向量到池中。"""
        if not isinstance(feature_vector, np.ndarray):
            raise TypeError("feature_vector must be a numpy array.")
        self.feature_deque.append(feature_vector)

    def get_feature_sequence(self):
        """
        获取当前的特征序列，用于输入到模型。
        如果特征不足，会用零向量在左侧填充。
        """
        current_sequence = list(self.feature_deque)
        current_len = len(current_sequence)
        
        if current_len == 0:
            # 获取第一个特征的维度
            first_feature_dim = 6400  # 根据 feature_edge_node_stimulate.ipynb，扁平化后是 256 * 25 = 6400
            return np.zeros((self.max_len, first_feature_dim))

        # 如果序列未满，进行左侧填充
        if current_len < self.max_len:
            padding_len = self.max_len - current_len
            feature_dim = current_sequence[0].shape[-1]
            padding = np.zeros((padding_len, feature_dim))
            return np.vstack([padding] + current_sequence)
        
        return np.array(current_sequence)

# %% [markdown]
# ## 保真模型 - 基于门控机制

# %%
class FidelityModelGated(nn.Module):
    def __init__(self, feature_dim, lstm_hidden_dim, raw_cnn_output_dim, num_classes=1):
        super(FidelityModelGated, self).__init__()
        self.lstm_hidden_dim = lstm_hidden_dim

        # 将 raw_cnn_output_dim 保存为实例属性
        self.raw_cnn_output_dim = raw_cnn_output_dim

        # 分支一：处理来自边缘节点的历史特征序列
        self.feature_lstm = nn.LSTM(
            input_size=feature_dim,
            hidden_size=lstm_hidden_dim,
            num_layers=2, # 使用两层LSTM增加模型深度
            batch_first=True, # 输入数据格式为 (batch, seq_len, feature_dim)
            dropout=0.5
        )

        # 分支二：处理高保真的原始传感器数据
        self.raw_data_cnn = create_raw_data_cnn()

        # 门控融合单元
        # 输入维度是LSTM输出和CNN输出的拼接
        self.gating_layer = nn.Sequential(
            nn.Linear(lstm_hidden_dim + raw_cnn_output_dim, lstm_hidden_dim),
            nn.ReLU(),
            nn.Linear(lstm_hidden_dim, 1),
            nn.Sigmoid()
        )

        # 将用于维度匹配的 raw_transform 层在 __init__ 中预先定义好
        self.raw_transform = nn.Linear(self.raw_cnn_output_dim, self.lstm_hidden_dim)

        # 最终分类器
        self.classifier = nn.Sequential(
            nn.Linear(lstm_hidden_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, num_classes)
        )

    def forward(self, feature_sequence, raw_data=None):
        """
        模型的前向传播。
        :param feature_sequence: (batch, seq_len, feature_dim) 的历史特征序列
        :param raw_data: (batch, 200, 11) 的原始传感器数据，或为 None
        :return: 模型的输出logits, LSTM的最后一个隐藏状态 (用于采样模型)
        """
        # 1. 处理历史特征序列
        lstm_outputs, (h_n, c_n) = self.feature_lstm(feature_sequence)
        
        # 只关心最后一个时间步的LSTM输出
        lstm_last_output = lstm_outputs[:, -1, :] # (batch, hidden_dim)

        # 2. 处理原始传感器数据 (如果可用)
        if raw_data is not None:
            # Conv1D需要 (batch, channels, length) 格式
            raw_data = raw_data.permute(0, 2, 1)
            v_raw = self.raw_data_cnn(raw_data) # (batch, raw_cnn_output_dim)
        else:
            # 使用预先保存的 self.raw_cnn_output_dim 创建零向量
            v_raw = torch.zeros(feature_sequence.size(0), self.raw_cnn_output_dim, device=feature_sequence.device)

        # 3. 门控融合
        # 计算门控值 g
        combined_for_gate = torch.cat((lstm_last_output, v_raw), dim=1)
        gate = self.gating_layer(combined_for_gate)
        
        # 直接使用在 __init__ 中定义好的 self.raw_transform 层
        transformed_v_raw = self.raw_transform(v_raw)

        fused_vector = lstm_last_output + gate * torch.tanh(transformed_v_raw)
        
        # 4. 分类
        logits = self.classifier(fused_vector)

        # 5. 返回结果和状态特征
        # h_n 的形状是 (num_layers, batch, hidden_dim), 取最后一层的状态
        state_feature = h_n[-1, :, :].squeeze(0) # (batch, hidden_dim)
        
        return logits, state_feature, gate.item()

# %% [markdown]
# ## 创建历史数据（从数据库中抽取数据）（暂未完成）

# %% [markdown]
# ## 模拟主流程

# %%
# --- 配置 ---
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
FEATURE_DIR = "simulated_features" # 从 feature_edge_node_stimulate.ipynb 生成的特征文件夹

# 模型超参数
# 来自 notebook: 256 (channels) * 25 (length)
FEATURE_DIM = 256 * 25 
LSTM_HIDDEN_DIM = 256
# 来自 create_raw_data_cnn(): 256 (channels) * 25 (length)
RAW_CNN_OUTPUT_DIM = 256 * 25 
HISTORY_SEQ_LEN = 60 # 使用过去30秒的历史特征 (60个特征点)

# --- 初始化 ---
print("Initializing Fidelity Model and Feature Pool...")
fidelity_model = FidelityModelGated(
    feature_dim=FEATURE_DIM,
    lstm_hidden_dim=LSTM_HIDDEN_DIM,
    raw_cnn_output_dim=RAW_CNN_OUTPUT_DIM
).to(DEVICE)

# --- 从 .pth 文件加载模型权重 ---
# 定义模型权重文件路径
model_path = 'fidelity_model_best.pth'

# 加载状态字典 (state_dict)
# 注意：map_location 参数很重要，它可以确保无论模型是在 GPU 还是 CPU 上训练的，都能正确加载。
print(f"Loading trained model weights from {model_path}...")
state_dict = torch.load(model_path, map_location=DEVICE)

# 将加载的权重应用到模型实例上
fidelity_model.load_state_dict(state_dict)
print("Model weights loaded successfully.")

fidelity_model.eval() # 设为评估模式，确保在推理时关闭 Dropout 和 Batch Normalization 的训练行为

feature_pool = HistoricalFeaturePool(max_sequence_length=HISTORY_SEQ_LEN)

# --- 加载从边缘节点模拟器生成的特征 ---
print(f"Loading features from '{FEATURE_DIR}'...")
if not os.path.exists(FEATURE_DIR):
    raise FileNotFoundError(f"Feature directory '{FEATURE_DIR}' not found. Please run the notebook first.")

feature_files = sorted([f for f in os.listdir(FEATURE_DIR) if f.endswith('.npy')])
all_features = [np.load(os.path.join(FEATURE_DIR, f)) for f in feature_files]
edge_feature_stream = np.vstack(all_features)
print(f"Loaded a total of {len(edge_feature_stream)} feature vectors.")

# --- 【待办】模拟从数据库加载部分历史原始数据 ---
# 在真实场景中，应该从数据库查询。这里创建一个虚拟数据
# 假设在第100和第250个时间步从边缘节点同步了原始数据
print("Simulating sparse historical raw data...")
dummy_raw_data_snippet = np.random.rand(200, 11) # 形状 (200, 11)
raw_data_availability = {
    100: dummy_raw_data_snippet,
    250: dummy_raw_data_snippet * 0.5 # 用不同数据模拟
}

# --- 主模拟循环 ---
print("\n--- Starting Fidelity Model Simulation ---\n")
for i, feature_vector in enumerate(edge_feature_stream):
    
    #【网络接口】模拟接收到新特征并添加到池中
    feature_pool.add_feature(feature_vector)
    
    # 从池中获取当前的历史序列
    current_feature_sequence = feature_pool.get_feature_sequence()
    
    # 检查当前时间步是否有可用的原始数据
    current_raw_data = raw_data_availability.get(i, None)
    
    # 准备输入张量
    seq_tensor = torch.tensor(current_feature_sequence, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    raw_tensor = torch.tensor(current_raw_data, dtype=torch.float32).unsqueeze(0).to(DEVICE) if current_raw_data is not None else None
    
    # 模型推理
    with torch.no_grad():
        logits, state_feature, gate_value = fidelity_model(seq_tensor, raw_tensor)

    # 解析和打印结果
    confidence = torch.sigmoid(logits).item()
    prediction = "FALL DETECTED!" if confidence > 0.5 else "No Fall"
    
    raw_data_info = "Yes" if current_raw_data is not None else "No"
    
    print(
        f"Step: {i+1:03d} | "
        f"Raw Data Used: {raw_data_info:<3} | "
        f"Gate Value: {gate_value:.2f} | "
        f"Confidence: {confidence:.4f} | "
        f"Prediction: {prediction:<15} | "
        f"State Feature Shape: {state_feature.shape}"
    )
# Out:
# Initializing Fidelity Model and Feature Pool...
# Loading trained model weights from fidelity_model_best.pth...
# Model weights loaded successfully.
# Historical Feature Pool initialized with max length 60.
# Loading features from 'simulated_features'...
# Loaded a total of 380 feature vectors.
# Simulating sparse historical raw data...
#
# --- Starting Fidelity Model Simulation ---
#
# Step: 001 | Raw Data Used: No  | Gate Value: 0.38 | Confidence: 0.9674 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 002 | Raw Data Used: No  | Gate Value: 0.29 | Confidence: 0.9984 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 003 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9996 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 004 | Raw Data Used: No  | Gate Value: 0.28 | Confidence: 0.9996 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 005 | Raw Data Used: No  | Gate Value: 0.31 | Confidence: 0.9992 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 006 | Raw Data Used: No  | Gate Value: 0.28 | Confidence: 0.9996 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 007 | Raw Data Used: No  | Gate Value: 0.29 | Confidence: 0.9995 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 008 | Raw Data Used: No  | Gate Value: 0.31 | Confidence: 0.9989 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 009 | Raw Data Used: No  | Gate Value: 0.35 | Confidence: 0.9977 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 010 | Raw Data Used: No  | Gate Value: 0.35 | Confidence: 0.9972 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 011 | Raw Data Used: No  | Gate Value: 0.38 | Confidence: 0.9937 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 012 | Raw Data Used: No  | Gate Value: 0.47 | Confidence: 0.9213 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 013 | Raw Data Used: No  | Gate Value: 0.57 | Confidence: 0.3775 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 014 | Raw Data Used: No  | Gate Value: 0.58 | Confidence: 0.2931 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 015 | Raw Data Used: No  | Gate Value: 0.46 | Confidence: 0.8537 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 016 | Raw Data Used: No  | Gate Value: 0.61 | Confidence: 0.1339 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 017 | Raw Data Used: No  | Gate Value: 0.88 | Confidence: 0.0036 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 018 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 019 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 020 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 021 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 022 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 023 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 024 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 025 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 026 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 027 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 028 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 029 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 030 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 031 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 032 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 033 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 034 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 035 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 036 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 037 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 038 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 039 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 040 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 041 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 042 | Raw Data Used: No  | Gate Value: 0.92 | Confidence: 0.0002 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 043 | Raw Data Used: No  | Gate Value: 0.91 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 044 | Raw Data Used: No  | Gate Value: 0.91 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 045 | Raw Data Used: No  | Gate Value: 0.90 | Confidence: 0.0005 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 046 | Raw Data Used: No  | Gate Value: 0.85 | Confidence: 0.0017 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 047 | Raw Data Used: No  | Gate Value: 0.89 | Confidence: 0.0007 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 048 | Raw Data Used: No  | Gate Value: 0.91 | Confidence: 0.0004 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 049 | Raw Data Used: No  | Gate Value: 0.92 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 050 | Raw Data Used: No  | Gate Value: 0.92 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 051 | Raw Data Used: No  | Gate Value: 0.88 | Confidence: 0.0008 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 052 | Raw Data Used: No  | Gate Value: 0.68 | Confidence: 0.0345 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 053 | Raw Data Used: No  | Gate Value: 0.53 | Confidence: 0.4594 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 054 | Raw Data Used: No  | Gate Value: 0.62 | Confidence: 0.1123 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 055 | Raw Data Used: No  | Gate Value: 0.87 | Confidence: 0.0043 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 056 | Raw Data Used: No  | Gate Value: 0.94 | Confidence: 0.0005 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 057 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 058 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 059 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 060 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 061 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 062 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 063 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 064 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 065 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 066 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 067 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 068 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 069 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 070 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 071 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 072 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 073 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 074 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 075 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 076 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 077 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 078 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 079 | Raw Data Used: No  | Gate Value: 0.91 | Confidence: 0.0005 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 080 | Raw Data Used: No  | Gate Value: 0.90 | Confidence: 0.0010 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 081 | Raw Data Used: No  | Gate Value: 0.89 | Confidence: 0.0018 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 082 | Raw Data Used: No  | Gate Value: 0.88 | Confidence: 0.0034 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 083 | Raw Data Used: No  | Gate Value: 0.77 | Confidence: 0.0211 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 084 | Raw Data Used: No  | Gate Value: 0.62 | Confidence: 0.1663 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 085 | Raw Data Used: No  | Gate Value: 0.48 | Confidence: 0.8267 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 086 | Raw Data Used: No  | Gate Value: 0.41 | Confidence: 0.9814 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 087 | Raw Data Used: No  | Gate Value: 0.34 | Confidence: 0.9970 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 088 | Raw Data Used: No  | Gate Value: 0.30 | Confidence: 0.9992 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 089 | Raw Data Used: No  | Gate Value: 0.28 | Confidence: 0.9996 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 090 | Raw Data Used: No  | Gate Value: 0.28 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 091 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 092 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 093 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 094 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 095 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 096 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 097 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 098 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 099 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 100 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 101 | Raw Data Used: Yes | Gate Value: 0.29 | Confidence: 0.9999 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 102 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 103 | Raw Data Used: No  | Gate Value: 0.28 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 104 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 105 | Raw Data Used: No  | Gate Value: 0.31 | Confidence: 0.9993 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 106 | Raw Data Used: No  | Gate Value: 0.37 | Confidence: 0.9964 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 107 | Raw Data Used: No  | Gate Value: 0.48 | Confidence: 0.9296 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 108 | Raw Data Used: No  | Gate Value: 0.73 | Confidence: 0.0236 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 109 | Raw Data Used: No  | Gate Value: 0.88 | Confidence: 0.0013 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 110 | Raw Data Used: No  | Gate Value: 0.92 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 111 | Raw Data Used: No  | Gate Value: 0.92 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 112 | Raw Data Used: No  | Gate Value: 0.91 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 113 | Raw Data Used: No  | Gate Value: 0.90 | Confidence: 0.0005 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 114 | Raw Data Used: No  | Gate Value: 0.85 | Confidence: 0.0017 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 115 | Raw Data Used: No  | Gate Value: 0.78 | Confidence: 0.0086 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 116 | Raw Data Used: No  | Gate Value: 0.93 | Confidence: 0.0006 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 117 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 118 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 119 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 120 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 121 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 122 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 123 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 124 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 125 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 126 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 127 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 128 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 129 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 130 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 131 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 132 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 133 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 134 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 135 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 136 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 137 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 138 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 139 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 140 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 141 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 142 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 143 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0002 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 144 | Raw Data Used: No  | Gate Value: 0.93 | Confidence: 0.0008 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 145 | Raw Data Used: No  | Gate Value: 0.90 | Confidence: 0.0024 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 146 | Raw Data Used: No  | Gate Value: 0.85 | Confidence: 0.0068 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 147 | Raw Data Used: No  | Gate Value: 0.77 | Confidence: 0.0218 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 148 | Raw Data Used: No  | Gate Value: 0.66 | Confidence: 0.0925 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 149 | Raw Data Used: No  | Gate Value: 0.53 | Confidence: 0.5479 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 150 | Raw Data Used: No  | Gate Value: 0.45 | Confidence: 0.9405 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 151 | Raw Data Used: No  | Gate Value: 0.38 | Confidence: 0.9900 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 152 | Raw Data Used: No  | Gate Value: 0.33 | Confidence: 0.9975 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 153 | Raw Data Used: No  | Gate Value: 0.29 | Confidence: 0.9993 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 154 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 155 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9998 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 156 | Raw Data Used: No  | Gate Value: 0.27 | Confidence: 0.9997 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 157 | Raw Data Used: No  | Gate Value: 0.29 | Confidence: 0.9996 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 158 | Raw Data Used: No  | Gate Value: 0.32 | Confidence: 0.9989 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 159 | Raw Data Used: No  | Gate Value: 0.58 | Confidence: 0.4280 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 160 | Raw Data Used: No  | Gate Value: 0.86 | Confidence: 0.0044 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 161 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 162 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 163 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 164 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 165 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 166 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 167 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 168 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 169 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 170 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 171 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 172 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 173 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 174 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 175 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 176 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 177 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 178 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 179 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 180 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 181 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 182 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 183 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 184 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 185 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 186 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 187 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 188 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 189 | Raw Data Used: No  | Gate Value: 0.92 | Confidence: 0.0016 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 190 | Raw Data Used: No  | Gate Value: 0.85 | Confidence: 0.0072 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 191 | Raw Data Used: No  | Gate Value: 0.74 | Confidence: 0.0358 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 192 | Raw Data Used: No  | Gate Value: 0.58 | Confidence: 0.2933 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 193 | Raw Data Used: No  | Gate Value: 0.46 | Confidence: 0.9166 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 194 | Raw Data Used: No  | Gate Value: 0.39 | Confidence: 0.9862 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 195 | Raw Data Used: No  | Gate Value: 0.34 | Confidence: 0.9958 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 196 | Raw Data Used: No  | Gate Value: 0.34 | Confidence: 0.9972 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 197 | Raw Data Used: No  | Gate Value: 0.33 | Confidence: 0.9980 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 198 | Raw Data Used: No  | Gate Value: 0.33 | Confidence: 0.9983 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 199 | Raw Data Used: No  | Gate Value: 0.33 | Confidence: 0.9982 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 200 | Raw Data Used: No  | Gate Value: 0.36 | Confidence: 0.9963 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 201 | Raw Data Used: No  | Gate Value: 0.32 | Confidence: 0.9985 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 202 | Raw Data Used: No  | Gate Value: 0.31 | Confidence: 0.9989 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 203 | Raw Data Used: No  | Gate Value: 0.38 | Confidence: 0.9937 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 204 | Raw Data Used: No  | Gate Value: 0.62 | Confidence: 0.2006 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 205 | Raw Data Used: No  | Gate Value: 0.87 | Confidence: 0.0046 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 206 | Raw Data Used: No  | Gate Value: 0.94 | Confidence: 0.0005 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 207 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 208 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 209 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 210 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 211 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 212 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 213 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 214 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 215 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 216 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 217 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 218 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 219 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 220 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 221 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 222 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 223 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 224 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 225 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 226 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 227 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 228 | Raw Data Used: No  | Gate Value: 0.94 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 229 | Raw Data Used: No  | Gate Value: 0.89 | Confidence: 0.0008 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 230 | Raw Data Used: No  | Gate Value: 0.92 | Confidence: 0.0004 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 231 | Raw Data Used: No  | Gate Value: 0.92 | Confidence: 0.0004 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 232 | Raw Data Used: No  | Gate Value: 0.89 | Confidence: 0.0010 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 233 | Raw Data Used: No  | Gate Value: 0.81 | Confidence: 0.0060 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 234 | Raw Data Used: No  | Gate Value: 0.68 | Confidence: 0.0481 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 235 | Raw Data Used: No  | Gate Value: 0.70 | Confidence: 0.0325 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 236 | Raw Data Used: No  | Gate Value: 0.53 | Confidence: 0.4786 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 237 | Raw Data Used: No  | Gate Value: 0.75 | Confidence: 0.0200 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 238 | Raw Data Used: No  | Gate Value: 0.80 | Confidence: 0.0136 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 239 | Raw Data Used: No  | Gate Value: 0.89 | Confidence: 0.0033 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 240 | Raw Data Used: No  | Gate Value: 0.93 | Confidence: 0.0010 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 241 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 242 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 243 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 244 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 245 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 246 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 247 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 248 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 249 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 250 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 251 | Raw Data Used: Yes | Gate Value: 0.95 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 252 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 253 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 254 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 255 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 256 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 257 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 258 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 259 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 260 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 261 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 262 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 263 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 264 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 265 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 266 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 267 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 268 | Raw Data Used: No  | Gate Value: 0.92 | Confidence: 0.0009 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 269 | Raw Data Used: No  | Gate Value: 0.86 | Confidence: 0.0045 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 270 | Raw Data Used: No  | Gate Value: 0.79 | Confidence: 0.0166 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 271 | Raw Data Used: No  | Gate Value: 0.65 | Confidence: 0.1026 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 272 | Raw Data Used: No  | Gate Value: 0.51 | Confidence: 0.6101 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 273 | Raw Data Used: No  | Gate Value: 0.43 | Confidence: 0.9499 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 274 | Raw Data Used: No  | Gate Value: 0.36 | Confidence: 0.9912 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 275 | Raw Data Used: No  | Gate Value: 0.31 | Confidence: 0.9981 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 276 | Raw Data Used: No  | Gate Value: 0.30 | Confidence: 0.9990 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 277 | Raw Data Used: No  | Gate Value: 0.29 | Confidence: 0.9995 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 278 | Raw Data Used: No  | Gate Value: 0.29 | Confidence: 0.9995 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 279 | Raw Data Used: No  | Gate Value: 0.25 | Confidence: 0.9998 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 280 | Raw Data Used: No  | Gate Value: 0.29 | Confidence: 0.9995 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 281 | Raw Data Used: No  | Gate Value: 0.47 | Confidence: 0.9477 | Prediction: FALL DETECTED!  | State Feature Shape: torch.Size([256])
# Step: 282 | Raw Data Used: No  | Gate Value: 0.80 | Confidence: 0.0131 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 283 | Raw Data Used: No  | Gate Value: 0.94 | Confidence: 0.0005 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 284 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 285 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 286 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 287 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 288 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 289 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 290 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 291 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 292 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 293 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 294 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 295 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 296 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 297 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 298 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 299 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 300 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 301 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 302 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 303 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 304 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 305 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 306 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 307 | Raw Data Used: No  | Gate Value: 0.94 | Confidence: 0.0002 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 308 | Raw Data Used: No  | Gate Value: 0.92 | Confidence: 0.0005 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 309 | Raw Data Used: No  | Gate Value: 0.90 | Confidence: 0.0012 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 310 | Raw Data Used: No  | Gate Value: 0.85 | Confidence: 0.0037 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 311 | Raw Data Used: No  | Gate Value: 0.90 | Confidence: 0.0010 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 312 | Raw Data Used: No  | Gate Value: 0.93 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 313 | Raw Data Used: No  | Gate Value: 0.94 | Confidence: 0.0002 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 314 | Raw Data Used: No  | Gate Value: 0.94 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 315 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 316 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 317 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 318 | Raw Data Used: No  | Gate Value: 0.91 | Confidence: 0.0004 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 319 | Raw Data Used: No  | Gate Value: 0.81 | Confidence: 0.0044 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 320 | Raw Data Used: No  | Gate Value: 0.94 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 321 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 322 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 323 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 324 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 325 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 326 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 327 | Raw Data Used: No  | Gate Value: 0.99 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 328 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 329 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 330 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 331 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 332 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 333 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 334 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 335 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 336 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 337 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 338 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 339 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 340 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 341 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 342 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 343 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 344 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 345 | Raw Data Used: No  | Gate Value: 0.92 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 346 | Raw Data Used: No  | Gate Value: 0.90 | Confidence: 0.0005 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 347 | Raw Data Used: No  | Gate Value: 0.90 | Confidence: 0.0006 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 348 | Raw Data Used: No  | Gate Value: 0.91 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 349 | Raw Data Used: No  | Gate Value: 0.94 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 350 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 351 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 352 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 353 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 354 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 355 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 356 | Raw Data Used: No  | Gate Value: 0.94 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 357 | Raw Data Used: No  | Gate Value: 0.91 | Confidence: 0.0003 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 358 | Raw Data Used: No  | Gate Value: 0.90 | Confidence: 0.0005 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 359 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 360 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 361 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 362 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 363 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 364 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 365 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 366 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 367 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 368 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 369 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 370 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 371 | Raw Data Used: No  | Gate Value: 0.98 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 372 | Raw Data Used: No  | Gate Value: 0.97 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 373 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 374 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0000 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 375 | Raw Data Used: No  | Gate Value: 0.96 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 376 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 377 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 378 | Raw Data Used: No  | Gate Value: 0.95 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 379 | Raw Data Used: No  | Gate Value: 0.94 | Confidence: 0.0001 | Prediction: No Fall         | State Feature Shape: torch.Size([256])
# Step: 380 | Raw Data Used: No  | Gate Value: 0.90 | Confidence: 0.0005 | Prediction: No Fall         | State Feature Shape: torch.Size([256])

# %% [markdown]
# ## 读懂结果
#
# * **`Raw Data Used`**: 显示当前推理步骤是否利用了高保真的原始数据。
# * **`Gate Value`**: 这是关键！当 `Raw Data Used` 为 `Yes` 时，如果这个值很低（例如\<0.5），说明模型判断新来的原始数据非常重要，更多地采纳了它。如果这个值很高（例如\>0.5），说明模型更相信自己基于历史特征的判断。当 `Raw Data Used` 为 `No` 时，这个值通常在0.5附近，因为全零的`v_raw`对门控影响不大。
# * **`Prediction`**: 最终的判断结果。
# * **`State Feature Shape`**: 这就是您要提供给采样模型的“状态特征”。它的形状是 `(1, 256)`（去掉了batch维度后是256），您可以直接将其传递给RL模型。
